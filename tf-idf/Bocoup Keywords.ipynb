# %% [markdown]
# # Bocoup Keywords
#
# ## Finding key terms on every page of Bocoup.com using tf-idf
#
# https://en.wikipedia.org/wiki/Tf%E2%80%93idf

# %% [markdown]
# ### 1. Download bocoup.com:

# %% [raw]
# $ wget --domains bocoup.com --html-extension --no-clobber bocoup.com

# %% [markdown]
# ### 2. Load Python libs

# %%
import os                           # Walking the file system and getting paths
import re                           # Regex
import sys                          # Getting the system-specific unicode range
import math                         # logarithms
import nltk                         # Tokenizing string
import unicodedata                  # Unicode character database, for building our exclude list

from bs4 import BeautifulSoup       # Parsing HTML
from collections import Counter     # dict subclass with handy features\
from __future__ import division     # make python2 divide good

# %% [markdown]
# ### 3. Define Characters to Exclude (Punctuation)
#
# We want to exclude most punctuation from our corpus for a couple of reasons:
#
# - We don't care about most of them (e.g. ellipses, apostrophes, etc.)
# - BeautifulSoup converts most HTML entities (usually used for punctuation, e.g. ellipses, "smart quotes") to unicode characters. When we later try to convert this unicode string to an ascii string (which is nicer for nltk to parse), we get encoding errors

# %%
punc = u''

# Loop through all characters in unicode, pulling out those that are punctuation
for i in xrange(sys.maxunicode):
    char = unichr(i)
    if unicodedata.category(char).startswith('P'): # Add exceptions here
        punc += char

exclude = set(punc)

# %% [markdown]
# ### 4. Set up containers for our word lists

# %%
# Count the number of documents that contain a token
token_document_count = Counter()

# Dict of site pages with counts of instances of each token on that page, keyed by document path
bocoup_com = {}

# %% [markdown]
# ### 5. Recursively walk the site, tokenizing text content

# %%
# Total number of documents in the data set
num_documents = 0

# We're going to walk the local bocoup.com directory
walk_dir = 'bocoup.com'

# Walk
for root, subdirs, files in os.walk(walk_dir):

    # Every file represent a page of the site
    for filename in files:
        
        # Should break this loop if the file isn't *.html
        
        # Add this file to the document count
        num_documents += 1

        # Get the path for this document
        file_path = os.path.join(root, filename)

        # Parse the html
        soup = BeautifulSoup(open(file_path), 'lxml')

        # Get rid of code examples, other tags whose text nodes would pollute our results
        for tag in soup.find_all(['code', 'head', 'iframe', 'pre', 'script', 'style']):
            tag.decompose()

        # Get contents of all text nodes, stripping extraneous whitespace
        clean_soup = soup.get_text(" ", strip=True).lower()
        
        # Remove URLs that appear in the text
        clean_soup = re.sub(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', '', clean_soup, flags=re.M)

        # Remove excluded characters from string
        clean_soup = ''.join([ch for ch in clean_soup if ch not in exclude])
        
        # Break string into discrete tokens
        tokens = nltk.word_tokenize(clean_soup)

        # Create a Counter with the resulting tokens
        document_tokens = Counter(tokens)
            
        # Count one more document appearance for each unique token in this file
        for token in document_tokens:
            token_document_count[token] += 1
        
        # Save the token counts for this document in our dict of all documents
        # Remove [index].html from this key, so it more closely resembles the URL
        bocoup_com[file_path.replace("/index.html", "").replace(".html", "")] = document_tokens

# %% [markdown]
# ### 6. Calculate Inverse Document Frequency for each term in the corpus
#
# The fewer documents a particular term appears in, the more "special" the term

# %%
idf = {}

for token in token_document_count:
    idf[token] = math.log(num_documents / token_document_count[token])

# %% [markdown]
# ### 7. Calculate tf-idf for each term in each document
#
# The number of times a term appears in a document multiplied by the inverse document frequency

# %%
tfidf = {}

for path in bocoup_com:
    
    # Use a Counter here for the sweet, sweet `most_common()` method we use below
    tfidf[path] = Counter()

    # Get the number of times the most common term on this page is used
    # We need this to normalize our frequency, below
    max_num = bocoup_com[path][max(bocoup_com[path], key=bocoup_com[path].get)]

    # Calculate the tf-idf for each word in this document
    for word in bocoup_com[path]:
        
        # Normalize to prevent bias towards longer docs
        tf = 0.5 + 0.5 * bocoup_com[path][word] / max_num
        
        # The tf-idf for this word in this document is the frequency this word appears 
        # in the document multiplied by its IDF (rarity in the corpus)
        tfidf[path][word] = tf * idf[word]

# %% [markdown]
# ### 8. Check it out

# %%
for path in tfidf:
    print(path)
    for tup in tfidf[path].most_common(10):
        print('--{}').format(tup[0].encode('utf-8'))
# Out:
# bocoup.com/education/classes/end-to-end-testing-and-continuous-integration.1
# --bh
# --photo
# --innovating
# --mastery
# --firsthand
# --creatively
# --educators
# --intensive
# --indepth
# --chicago
# bocoup.com/about/bocouper/jasmin-jata
# --ceramic
# --rose
# --kelleher
# --cephalopod
# --reveling
# --biology
# --scientific
# --outlook
# --unknown
# --overlords
# bocoup.com/weblog/training-jquery-san-francisco
# --guy
# --proceeds
# --enhancing
# --struggled
# --dabbled
# --traversing
# --val
# --primer
# --299
# --beginner
# bocoup.com/weblog/git-workflow-walkthrough-reviewing-pull-requests
# --yannicks
# --biggiethat
# --commenting
# --submitter
# --coder
# --spot
# --pretend
# --merely
# --accident
# --occur
# bocoup.com/weblog/tag/johnny-five
# --milliamps
# --paired
# --measurement
# --programmed
# --electronic
# --lipo
# --easilydiscoverable
# --motor
# --pasting
# --precious
# bocoup.com/weblog/organizing-your-backbone-js-application-with-modules
# --applicationjs
# --memoizing
# --applicationreadyjs
# --buddy
# --namespaces
# --elegant
# --helperjs
# --naivejs
# --mutable
# --encapsulated
# bocoup.com/weblog/game-dev-montreal
# --250
# --montreal
# --rebate
# --295
# --quebec
# --140
# --studio
# --canadian
# --crim
# --box2d
# bocoup.com/weblog/how-nodejs-makes-network-code-more-testable
# --asserts
# --rendr
# --fires
# --configures
# --timeconsuming
# --confirms
# --nodeunit
# --disconnected
# --responses
# --traditionally
# bocoup.com/education/bocoup-jquery-essentials-tour
# --bh
# --photo
# --innovating
# --mastery
# --firsthand
# --creatively
# --educators
# --intensive
# --indepth
# --chicago
# bocoup.com/about/bocouper/leo-balter
# --cep
# --neutrality
# --msx
# --attends
# --riojs
# --horaextra
# --lawyer
# --braziljs
# --rio
# --promovendo
# bocoup.com/weblog/breaking-rules-in-tests
# --systemic
# --transcription
# --globals
# --procedurallygenerated
# --positives
# --alternatives
# --pride
# --retype
# --reinterpret
# --solves
# bocoup.com/weblog/communicating-between-views-in-client-side-apps
# --pubsub
# --occurrences
# --torn
# --downsides
# --srchr
# --fireandforget
# --parentchild
# --generalize
# --abundant
# --batched
# bocoup.com/weblog/welcome-cassie-irwin
# --engineermanagement
# --qa
# --austens
# --jane
# --muse
# --coordinated
# --scrabble
# --il
# --oversaw
# --worst
# bocoup.com/weblog/tag/web-connected-devices
# --milliamps
# --paired
# --measurement
# --programmed
# --electronic
# --lipo
# --easilydiscoverable
# --motor
# --pasting
# --precious
# bocoup.com/weblog/javascript-web-workers-support-testing-the-browser
# --concurrency
# --spawns
# --oslevel
# --definitive
# --serialized
# --nonthread
# --threads
# --primer
# --multicore
# --nonblocking
# bocoup.com/weblog/new-overflow-default
# --pen
# --incompl
# --scrollbars
# --sizing
# --codepen
# --ckmdq
# --badly
# --awry
# --ie7+
# --slap
# bocoup.com/weblog/ringmark-tests-open-source
# --testharnessjs
# --ratify
# --wellformed
# --testharness
# --facebookcoremobtests
# --futureproof
# --coremob
# --silos
# --inconsistent
# --shim
# bocoup.com/weblog/category/media
# --transcript
# --ching
# --soaked
# --entertaining
# --backchannel
# --badoom
# --landmark
# --sketched
# --speckling
# --broadway
# bocoup.com/weblog/building-html5-games-with-gsn
# --gsns
# --solitaire
# --crafty
# --analysts
# --iosreorient
# --precompiled
# --shortage
# --repeating
# --madeto
# --revenue
# bocoup.com/weblog/tag/training
# --bananathemed
# --liveliness
# --1011
# --scheduled
# --lively
# --diego
# --guiding
# --slated
# --fade
# --rails
# bocoup.com/about/bocouper/jenn-schiffer
# --jersey
# --satire
# --sorting
# --monetizing
# --dunk
# --ventures
# --css™
# --attract
# --tries
# --make8bitartcom
# bocoup.com/weblog/implementing-the-google-contacts-authsub-flow-with-jquery
# --gdata
# --authsub
# --revoke
# --googlecontactsauthsubhtml
# --authenticating
# --https
# --googlecontactsauthsubjs
# --contacts
# --handshake
# --oauth
# bocoup.com/weblog/welcome-corey-frang
# --coreys
# --scientist
# --gnarf
# --respect
# --freenode
# --deeply
# --colleague
# --directors
# --committer
# --talents
# bocoup.com/weblog/sponsoring-diversity-scholarships-for-braziljs
# --scholarship
# --applicants
# --welcomed
# --eligible
# --heartfelt
# --evaluators
# --vented
# --devoted
# --perspectives
# --accommodation
# bocoup.com/work/learn-js-data
# --outlining
# --lodash
# --crunching
# --classrooms
# --munging
# --webbased
# --manipulating
# --demonstrated
# --enabling
# --breeze
# bocoup.com/presentations/scoping-javascript-scope
# --collector
# --garbage
# --relates
# --beginner
# --closures
# --hardest
# --scoping
# --intermediate
# --mostly
# --aimed
# bocoup.com/weblog/bocoup-gamelab
# --mikeal
# --abacus
# --rogers
# --broadened
# --hinges
# --crossing
# --funded
# --gamelab
# --begun
# --ogden
# bocoup.com/weblog/welcome-tyler-kellen
# --selfreliant
# --homestead
# --tylers
# --documenting
# --mountain
# --tara
# --forest
# --national
# --traveling
# --nodetask
# bocoup.com/weblog/backbone-training-london
# --internationally
# --netherlands
# --canada
# --france
# --threeday
# --germany
# --reserve
# --roots
# --london
# --intimate
# bocoup.com/weblog/new-worker-expanding-capabilities-of-javascript-web-workers
# --indexphp
# --workerjsphp
# --type=button
# --unzip
# --id=post
# --locahost
# --xmlhttprequest
# --saveas
# --xhrtestcontenttxt
# --workerssimplezip
# bocoup.com/weblog/welcome-mike-pennisi
# --prototypejs
# --jedi
# --lessjs
# --butt
# --exuberance
# --vodafone
# --enormous
# --modernizr
# --totally
# --kick
# bocoup.com/weblog/au-revoir-garde-nord
# --temporary
# --reopening
# --spaces
# --snag
# --landlord
# --shut
# --ballrooms
# --outdoor
# --gorgeous
# --renevation
# bocoup.com/presentations/growing-up-wordpress
# --tenyear
# --retrospective
# --wordpresstv
# --jenn
# --wordpress
# --schiffer
# --growing
# --gives
# --watch
# --presentation
# bocoup.com/weblog/introducing-learnjsdata
# --deficiency
# --learnjsdatacom
# --wrangling
# --munging
# --spanish
# --gap
# --scripting
# --collaborators
# --chapter
# --fill
# bocoup.com/weblog/welcome-greg-smith
# --gsmith
# --sprucedup
# --rpg
# --kickstarterfunded
# --rd
# --11th
# --likes
# --electronic
# --upcoming
# --hell
# bocoup.com/weblog/tag/open-source/page/3
# --blast
# --typos
# --literals
# --misprinted
# --objectlateralcom
# --murphy
# --laterals
# --enormously
# --generous
# --lateral
# bocoup.com/weblog/tag/open-source/page/2
# --openhatch
# --responders
# --avenues
# --advocates
# --nonprofit
# --prospective
# --threshold
# --whod
# --safety
# --marked
# bocoup.com/weblog/customizing-the-robotsconf-sumobot-with-johnny-five
# --jumpers
# --stopped
# --imagination
# --dictate
# --possibilities
# --infinite
# --calibrate
# --10kω
# --observe
# --directed
# bocoup.com/weblog/author/ben-alman
# --trycatch
# --portland
# --francisco
# --san
# --31
# --catch
# --alman
# --grunt
# --ben
# --engineer
# bocoup.com/weblog/ember-training-with-tilde
# --tilde
# --newlyformed
# --katz
# --tom
# --yehuda
# --2224
# --dale
# --mv
# --emberjs
# --25th
# bocoup.com/weblog/author/sue-lockwood
# --nosql
# --godzilla
# --neuropsychology
# --loving
# --illustrator
# --baker
# --db
# --dribbble
# --drawings
# --fauxton
# bocoup.com/weblog/mobile-datavis-grant
# --industrydefined
# --summarizing
# --2425th
# --communitys
# --culminate
# --loud
# --recurring
# --visualizaiton
# --emphasizing
# --surveying
# bocoup.com/weblog/announcing-new-game-conference
# --sponsor
# --1st
# --2nd
# --viable
# --feed
# --transition
# --crucial
# --info
# --presenting
# --francisco
# bocoup.com/weblog/html5-video-synchronizing-playback-of-two-videos
# --fiddle
# --resync
# --subtly
# --combo
# --timeupdate
# --upped
# --html5demoscom
# --behaviours
# --quietly
# --noting
# bocoup.com/weblog/lessons-from-scrum
# --backlog
# --sidebar
# --selforganization
# --increment
# --problemsolving
# --tracer
# --timeboxed
# --promotes
# --spike
# --bullet
# bocoup.com/presentations/building-better-apps-with-client-side-data
# --30
# --clientside
# --apps
# --nov
# --better
# --irene
# --ros
# --2012
# --building
# --newsletter
# bocoup.com/weblog/dive-into-flexbox
# --flex
# --flexstart
# --flexend
# --axes
# --adjusts
# --writingmode
# --flexwrap
# --child
# --centering
# --lefttoright
# bocoup.com/weblog/welcome-evelyn-eastmond
# --evelyn
# --smalltalk
# --evelyns
# --mits
# --eastmond
# --intersection
# --artist
# --serving
# --porting
# --12th
# bocoup.com/weblog/javascript-led-matrix-display-with-johnny-five
# --8×8
# --elect
# --ata
# --cl
# --oneatatime
# --0255
# --oc
# --8bit
# --din
# --clk
# bocoup.com/presentations/bits-of-nodebots-next
# --bits
# --slides
# --download
# --06
# --nodebots
# --waldron
# --rick
# --may
# --next
# --2014
# bocoup.com/about/bocouper/darius-kazemi
# --sale
# --hubway
# --rapbot
# --particle
# --benchmarking
# --reconstitution
# --uniforms
# --deconstruction
# --fieldrunners
# --hack
# bocoup.com/weblog/welcome-rebecca-murphey
# --acted
# --reflective
# --rebeccas
# --accomplishments
# --leader
# --driving
# --yayquery
# --roles
# --collaborator
# --fundamentals
# bocoup.com/weblog/ansible-based-deployment-workflow-for-modern-webapps-and-websites
# --heroku
# --providerspecific
# --twohour
# --deploymentworkflowbocoupcom
# --byproduct
# --dreamhost
# --offerings
# --greatim
# --pipelines
# --doubly
# bocoup.com/weblog/3pjs-css-defense
# --defensively
# --inserting
# --paragraphs
# --ta
# --capncrunch
# --cascading
# --escalation
# --filled
# --resets
# --sourceful
# bocoup.com/weblog/getting-started-with-mozilla-gaia
# --augment
# --proven
# --gaianotes
# --screencast
# --b2g
# --acquainted
# --firstclass
# --fresh
# --digging
# --fixes
# bocoup.com/weblog/tag/microprocessor
# --laser
# --intrusion
# --sucess
# --composition
# --probability
# --validations
# --commited
# --breakthrough
# --validation
# --triage
# bocoup.com/weblog/call-for-writers-microsoft
# --quotes
# --gdc
# --crack
# --unseen
# --breakouts
# --demonstrations
# --penchant
# --html5rockscom
# --typographers
# --footnotes
# bocoup.com/about/bocouper/mike-pennisi
# --srcdoc
# --backbonelayoutmanager
# --develops
# --mikes
# --privacy
# --dressup
# --interests
# --networking
# --polyfill
# --peer
# bocoup.com/weblog/summer-2015-bocoup-cssconf-txjs-roost-and-you
# --revival
# --famous
# --laying
# --wednesday
# --sustaining
# --cssconfs
# --latebreaking
# --star
# --everybodys
# --fashioned
# bocoup.com/weblog/spoofing-user-agent-with-chromes-webrequest-api
# --requestfilter
# --diffminded
# --requestheadersjson
# --spoof
# --designation
# --manifest
# --backgroundjs
# --printout
# --manifestjson
# --usecase
# bocoup.com/about/bocouper/tim-branyen
# --clientcentric
# --grail
# --holy
# --synchronizing
# --organizing
# --angularjs
# --boilerplate
# --growing
# --tim
# --branyen
# bocoup.com/weblog/tag/nodebots
# --flipflop
# --sequential
# --roadways
# --deli
# --signs
# --wellproven
# --airports
# --grocery
# --alarm
# --colossus
# bocoup.com/education/classes/building-web-applications-with-angular
# --bh
# --photo
# --innovating
# --mastery
# --firsthand
# --creatively
# --educators
# --intensive
# --indepth
# --chicago
# bocoup.com/weblog/jshint-at-bocoup
# --stewarding
# --footsteps
# --promoting
# --preference
# --overseeing
# --honored
# --anton
# --24th
# --shares
# --maintainer
# bocoup.com/education/classes/building-server-side-apps-with-node-and-express
# --bh
# --photo
# --innovating
# --mastery
# --firsthand
# --creatively
# --educators
# --intensive
# --indepth
# --chicago
# bocoup.com/weblog/javascript-arduino-bumper-switch-controlling-led-tutorial
# --10k
# --ohm
# --tapping
# --buttonbumperjs
# --switchbutton
# --seven
# --onoff
# --bumper
# --9v
# --grounded
# bocoup.com/about/bocouper/matt-surabian
# --fishing
# --hunting
# --taryn
# --devops
# --stuffing
# --backpacking
# --cooking
# --kitchen
# --continues
# --wife
# bocoup.com/services/web-applications
# --behold
# --inthetrenches
# --everchanging
# --flashsale
# --boutiques
# --duolingos
# --merchandise
# --reflects
# --ownership
# --duolingo
# bocoup.com/weblog/tag/web-standards
# --ecmatc39
# --weinstein
# --rafael
# --fantastical
# --adventure
# --programatically
# --flipped
# --262
# --objectobserve
# --analyzed
# bocoup.com/presentations/sorting-algorithms
# --sorting
# --schiffer
# --jenn
# --slides
# --download
# --05
# --may
# --2014
# --out
# --newsletter
# bocoup.com/weblog/newsweek-raphaeljs-career-tree-visualization-raphaeljs-burst
# --jason
# --leaf
# --catalano
# --visualizes
# --employment
# --diameter
# --diamond
# --graceful
# --tree
# --outstanding
# bocoup.com/text/weblog/node-stress-test-service
# --nodeuser
# --designated
# --syslog
# --localfs
# --remotefs
# --etcinitdnodeservice
# --redisserver
# --binbash
# --startstopdaemon
# --ulimit
# bocoup.com/weblog/welcome-christine-an
# --temporally
# --www
# --digitally
# --zines
# --manifested
# --ocassionally
# --31st
# --comics
# --stine
# --salon
# bocoup.com/weblog/fieldrunners-playing-to-the-strengths-of-html5-audio-and-web-audio
# --mp3
# --decompression
# --universallyaccepted
# --sonic
# --degrades
# --chromeflags
# --nonwebapisupporting
# --silent
# --collectioncumbersome
# --inbrowser
# bocoup.com/services
# --satisfy
# --impacts
# --toughest
# --updatable
# --fluent
# --bestinclass
# --interdisciplinary
# --uncover
# --wellrounded
# --bulletproof
# bocoup.com/weblog/bocoup-and-pbs-realtime
# --postmortem
# --vanessa
# --daub
# --contextualized
# --justin
# --myers
# --drills
# --dennis
# --onset
# --moskowitz
# bocoup.com/work/open-vis-conf
# --tshirts
# --mugs
# --proudly
# --projections
# --drew
# --iconic
# --wear
# --matte
# --generative
# --evoking
# bocoup.com/weblog/welcome-irene-ros
# --lotus
# --intelligence
# --excel
# --dojo
# --ireneros
# --researchs
# --ibm
# --raphaeljs
# --notes
# --jumping
# bocoup.com/weblog/category/testing
# --testings
# --nothings
# --cherry
# --unmaintainable
# --till
# --hurdle
# --deciphering
# --slog
# --necessity
# --skill
# bocoup.com/services/training/classes/building-web-applications-with-angular
# --filters
# --repeaters
# --xhrs
# --modelviewcontroller
# --thin
# --directives
# --injection
# --ideal
# --sublimetext
# --templating
# bocoup.com/weblog/experience-as-a-bocoup-fellow
# --postopic
# --bike
# --mongoose
# --accessing
# --mentor
# --intense
# --slug
# --sinon
# --bootstrap
# --crash
# bocoup.com/education/html5-for-programmers
# --bh
# --photo
# --innovating
# --mastery
# --firsthand
# --creatively
# --educators
# --intensive
# --indepth
# --chicago
# bocoup.com/weblog/controlling-the-robotsconf-sumobot-with-electric-imp-johnny-five.1
# --imp001
# --factors
# --jr
# --sumbobot
# --q
# --reverse
# --adapted
# --customizations
# --pwm
# --mappings
# bocoup.com/weblog/javascript-enumerable-map-with-webworkers
# --reassembles
# --parallelizable
# --mapreduce
# --bare
# --bones
# --pool
# --preserved
# --standardization
# --spans
# --webworker
# bocoup.com/work/surging-seas-risk-finder
# --rising
# --localized
# --legislators
# --region
# --traction
# --levels
# --transportation
# --centrals
# --approachable
# --advocacy
# bocoup.com/holiday-gift
# --zip
# --wintry
# --opensourced
# --gift
# --season
# --designits
# --icons
# --illustrations
# --2016
# --svgs
# bocoup.com/weblog/fieldrunners-webgl-particle-system-demo
# --towers
# --enemies
# --spacing
# --rowscolumns
# --16×16
# --rxc
# --tower
# --lightning
# --patient
# --shoot
# bocoup.com/about/bocouper/jory-burson
# --longterm
# --literacy
# --companywide
# --pilots
# --realization
# --operationalize
# --mediumterm
# --organizational
# --compass
# --participation
# bocoup.com/weblog/vintage-visualization-restoration-bump-chart
# --pill
# --henry
# --pills
# --gannett
# --hackedup
# --petersburg
# --recoding
# --seemingly
# --visuals
# --defeat
# bocoup.com/weblog/javascript-rotoscoping-tool
# --timelinekeyframe
# --buttercamp
# --aboutflags
# --entrepreneur
# --localstorage
# --unreliably
# --pursue
# --mak
# --animators
# --rotoscoping
# bocoup.com/weblog/bem-vindo-leo-balter
# --longboarding
# --guitar
# --felizes
# --dr
# --portuguese
# --lawyer
# --muito
# --abroad
# --relaxing
# --episode
# bocoup.com/weblog/announcing-opengendertracker
# --newsrooms
# --dedicating
# --anecdotally
# --accurately
# --invest
# --pushes
# --beats
# --easytointegrate
# --easytodeploy
# --opengendertracker
# bocoup.com/services/web-connected-devices
# --microprocessors
# --productionquality
# --programmable
# --affordable
# --alike
# --onboarding
# --fullstack
# --stabilize
# --maintained
# --iot
# bocoup.com/weblog/tag/data-visualization
# --ceiling
# --shoulders
# --baur
# --dominikus
# --reimplement
# --jeff
# --bump
# --wongsuphasawat
# --dominik
# --vintage
# bocoup.com/weblog/introducing-gith-github-webhooks-for-node
# --payloads
# --saves
# --tagging
# --accomplishes
# --simplifies
# --alerted
# --secret=password
# --githooks
# --querystringargument
# --subscribing
# bocoup.com/weblog/the-catch-with-try-catch
# --fabricated
# --clause
# --810
# --fwiw
# --declarationleakage
# --leakage
# --backstory
# --excursion
# --undeclared
# --asexpected
# bocoup.com/html/weblog/npmbynumbers-analysis
# --median
# --dependend
# --210
# --~12
# --~18
# --4477
# --05197
# --95
# --semver
# --2771
# bocoup.com/about/bocouper/bob-holt
# --wilds
# --hampshire
# --ceejs
# --domaindriven
# --photography
# --topnotch
# --homegrowing
# --ant
# --contributes
# --quest
# bocoup.com/about/bocouper/corey-frang
# --stackoverflow
# --gnarf
# --rewrote
# --confessions
# --maintains
# --cdpath
# --pronouns
# --committer
# --scoping
# --hacking
# bocoup.com
# --greetings
# --illuminate
# --breathtaking
# --seasons
# --splash
# --imax
# --deepen
# --champions
# --strengthening
# --forging
# bocoup.com/education/online/screencasts/dry-out-your-code-with-functions.1
# --bh
# --photo
# --innovating
# --mastery
# --firsthand
# --creatively
# --educators
# --intensive
# --indepth
# --chicago
# bocoup.com/weblog/introducing-miso-project-and-dataset-library
# --obtain
# --fasttotraverse
# --subscription
# --spreadsheets
# --computational
# --minmax
# --bridges
# --sparklines
# --interoperability
# --queried
# bocoup.com/presentations/the-abcs-of-data-visualization
# --abcs
# --29
# --irene
# --ros
# --2013
# --may
# --newsletter
# --email
# --hellobocoupcom
# --touch
# bocoup.com/weblog/reusability-with-d3
# --modifiable
# --refactored
# --fading
# --interpretations
# --interpretation
# --coloredlabel
# --pejorative
# --lowtech
# --chord
# --manages
# bocoup.com/weblog/assembling-preparing-robotsconf-sumobot-with-johnny-five.1
# --pulse
# --screws
# --aa
# --typeb
# --pane
# --caster
# --regulate
# --calibrated
# --tyrion
# --solderless
# bocoup.com/presentations/marionette-js-the-backbone-framework
# --marionettejs
# --explains
# --james
# --extension
# --motivation
# --benefit
# --size
# --behind
# --provides
# --popular
# bocoup.com/weblog/author/darius-kazemi
# --sale
# --hubway
# --rapbot
# --particle
# --benchmarking
# --reconstitution
# --uniforms
# --deconstruction
# --fieldrunners
# --hack
# bocoup.com/weblog/category/fieldrunners
# --rebate
# --837
# --studio
# --295
# --canadian
# --crim
# --standingroomonly
# --14000
# --quebec
# --140
# bocoup.com/weblog/javascript-object-observe
# --notify
# --optimized
# --observation
# --changerecords
# --delivery3js
# --completethats
# --goodies
# --notifiers
# --latching
# --atrocious
# bocoup.com/weblog/javascript-arduino-servo-control-tutorial
# --inventors
# --supplemented
# --sparkfun
# --setupjs
# --commandsjs
# --investing
# --makersheds
# --supplies
# --100ms
# --addservojs
# bocoup.com/weblog/good-bye-darius
# --refreshes
# --farewell
# --letter
# --brilliance
# --genius
# --genre
# --bots
# --gravitas
# --touched
# --excitement
# bocoup.com/about/bocouper/christine-an
# --sector
# --kafka
# --peaches
# --ukulele
# --bream
# --austrohungarian
# --czech
# --clubs
# --reform
# --deadpan
# bocoup.com/about/bocouper/irene-ros/page/4
# --joystick
# --nightly
# --trends
# --collections
# --introduces
# --organizing
# --startup
# --08
# --director
# --dom
# bocoup.com/datavis.1
# --topcaliber
# --famine
# --somalia
# --instructional
# --academia
# --crisis
# --userfriendly
# --mapbased
# --144
# --flowcontrol
# bocoup.com/education/classes/writing-testable-javascript.1
# --bh
# --photo
# --innovating
# --mastery
# --firsthand
# --creatively
# --educators
# --intensive
# --indepth
# --chicago
# bocoup.com/weblog/controlling-the-robotsconf-sumobot-with-spark-core-johnny-five.1
# --factor
# --jr
# --sumbobot
# --q
# --reverse
# --adapted
# --couple
# --customizations
# --pwm
# --mappings
# bocoup.com/weblog/new-training-intro-to-game-dev
# --spots
# --signup
# --box2d
# --standingroomonly
# --soldout
# --keenly
# --nyu
# --2d
# --straight
# --inhouse
# bocoup.com/presentations/rick-waldron-es6-my-favorite-parts
# --pipeline
# --discusses
# --es6
# --presentation
# --favorite
# --coming
# --slides
# --download
# --parts
# --22
# bocoup.com/presentations/johnny-five-js-robots
# --robots
# --slides
# --02
# --download
# --johnnyfive
# --jul
# --waldron
# --rick
# --2012
# --newsletter
# bocoup.com/weblog/bocoup-recommits-to-boston-innovation-district
# --lounge
# --recommit
# --collaborations
# --sponsorships
# --luckys
# --celebration
# --exhaustive
# --42
# --bostons
# --lectures
# bocoup.com/education/classes/tracks
# --bh
# --photo
# --innovating
# --mastery
# --firsthand
# --creatively
# --educators
# --intensive
# --indepth
# --chicago
# bocoup.com/weblog/jquery-twitter-search-feed
# --jquerytwitterfeedcss
# --jquerytwitterfeedjs
# --dead
# --indexhtml
# --feed
# --explained
# --bocoupcom
# --10th
# --search
# --styles
# bocoup.com/weblog/jquery-docs-keyboard-navigation
# --searchkeyboard
# --formatting
# --jquerykeynav
# --chaffers
# --swedberg
# --johns
# --nunemakers
# --wroterewrote
# --jonathan
# --hostetlers
# bocoup.com/education/classes/building-modular-applications
# --bh
# --photo
# --innovating
# --mastery
# --firsthand
# --creatively
# --educators
# --intensive
# --indepth
# --chicago
# bocoup.com/weblog/our-work-with-data-voyager
# --voyagers
# --firstuse
# --uploaded
# --punch
# --uxui
# --bon
# --preloaded
# --littletono
# --footer
# --hierarchy
# bocoup.com/search/web-workers/page/2
# --hacksession
# --nightlies
# --coolest
# --firebug
# --webworkers
# --macdonald
# --resig
# --al
# --badass
# --35
# bocoup.com/weblog/popcorn-js
# --feeds
# --eachother
# --enormously
# --generous
# --flickr
# --anna
# --ircmozillaorgpopcorn
# --humphrey
# --gaylor
# --viewer
# bocoup.com/weblog/open-source-everything-working-with-jquery-foundation
# --demoralized
# --hesitant
# --swept
# --territory
# --ripe
# --muscles
# --fodder
# --commitless
# --threshold
# --avenues
# bocoup.com/weblog/welcome-matt-surabian
# --duck
# --outdoorman
# --scituate
# --matts
# --avid
# --hunt
# --ceros
# --pursuits
# --glad
# --varied
# bocoup.com/weblog/foundations-of-programming-with-javascript
# --hangman
# --presentationoriented
# --brains
# --inclass
# --dissect
# --memorizing
# --allday
# --belief
# --coordinator
# --hunt
# bocoup.com/education/classes/web-developer-tools-and-workflow
# --bh
# --photo
# --innovating
# --mastery
# --firsthand
# --creatively
# --educators
# --intensive
# --indepth
# --chicago
# bocoup.com/weblog/javascript-tilt-sensor-with-johnny-five
# --conductive
# --mercury
# --d7
# --detected
# --30°
# --audibly
# --inclinition
# --shorted
# --blob
# --material
# bocoup.com/education/classes/javascript-for-engineers.1
# --bh
# --photo
# --innovating
# --mastery
# --firsthand
# --creatively
# --educators
# --intensive
# --indepth
# --chicago
# bocoup.com/weblog/author/pete-karl
# --bisbee
# --peek
# --inpage
# --writers
# --googles
# --sam
# --cassie
# --irwin
# --richard
# --analytics
# bocoup.com/presentations/things-you-might-not-know-about-jquery-by-john-resig
# --resig
# --john
# --slides
# --download
# --2010
# --28
# --oct
# --might
# --know
# --jquery
# bocoup.com/weblog/pollenjs-javascript-web-workers-library
# --pollenjs
# --learningusing
# --isfn
# --isundef
# --regarding
# --isnum
# --inarray
# --toarray
# --isnull
# --decode
# bocoup.com/weblog/tag/responsive
# --rallying
# --ricgs
# --wind
# --tackles
# --justice
# --responsiveness
# --d3chartjs
# --functioning
# --5dimensional
# --starttofinish
# bocoup.com/work/johnny-five
# --hexapods
# --idiomatic
# --ioplugins
# --roadshow
# --eventbased
# --jquerylike
# --broadening
# --systemonachip
# --potentiometers
# --confines
# bocoup.com/weblog/goiabada
# --goiabada
# --goiabadas
# --guava
# --rescue
# --protection
# --salty
# --respective
# --constants
# --delightful
# --mdn
# bocoup.com/work/syria-conflict-interactive-maps
# --amend
# --reporters
# --longreads
# --photography
# --pertaining
# --locate
# --refugee
# --analyze
# --editorial
# --mapbased
# bocoup.com/weblog/git-workflow-walkthrough-feature-branches
# --leveled
# --toes
# --integrations
# --mail
# --clobbering
# --loosely
# --corrupting
# --branchthis
# --bea
# --iros
# bocoup.com/about/bocouper/jim-vallandingham
# --bioinformatic
# --digest
# --sunny
# --frantically
# --learnings
# --interactives
# --landscapes
# --scientist
# --enjoying
# --consuming
# bocoup.com/weblog/tag/web-connected-devices/page/3
# --electronics
# --tuesday
# --microcenter
# --artists
# --hobbyists
# --easytouse
# --bumper
# --purchased
# --closest
# --nodeserialport
# bocoup.com/weblog/tag/web-connected-devices/page/2
# --creations
# --geek
# --arduinos
# --dancing
# --wireless
# --restrictive
# --hostclient
# --flipflop
# --inclination
# --borenstein
# bocoup.com/weblog/bocoup-training-portland-or
# --adventurous
# --luke
# --fragomeni
# --mixandmatch
# --squires
# --robbins
# --paolo
# --leroux
# --marak
# --charlie
# bocoup.com/about/bocouper/jess-klein
# --communitydesigned
# --passions
# --preparedness
# --venn
# --hyperlocal
# --emergency
# --rebuilding
# --rockaway
# --hacktivism
# --cofounded
# bocoup.com/about/bocouper/claire-rittershaus
# --castles
# --shipshape
# --laughing
# --hikes
# --claire
# --shells
# --dogs
# --organizer
# --staying
# --heart
# bocoup.com/weblog/npm-by-numbers
# --skimdb
# --waffle
# --88
# --ipython
# --indirect
# --replica
# --71000
# --101
# --scratched
# --surpassed
# bocoup.com/presentations/exploding-your-wordpress-theme-with-css3
# --exploding
# --css3
# --wordpress
# --theme
# --sender
# --boaz
# --23
# --2011
# --jul
# --your
# bocoup.com/weblog/tag/web-standards/page/2
# --nightlies
# --whatwg
# --threadsafe
# --hacksession
# --shallow
# --evangelist
# --inconsistant
# --threading
# --jquerylooking
# --multi
# bocoup.com/education/online/screencasts/dry-out-your-code-with-functions
# --bh
# --photo
# --innovating
# --mastery
# --firsthand
# --creatively
# --educators
# --intensive
# --indepth
# --chicago
# bocoup.com/presentations/jquery-animation
# --animation
# --frang
# --corey
# --slides
# --download
# --nov
# --12
# --2012
# --jquery
# --newsletter
# bocoup.com/weblog/after-the-ricg
# --tooand
# --specand
# --labor
# --ourselvesto
# --premium
# --advances
# --lovenights
# --momentum
# --laserfocused
# --blogged
# bocoup.com/weblog/javascript-web-workers-from-basics-to-jquery-hive-part-i
# --onmessage
# --clarifications
# --`window`
# --loss
# --workerpool
# --multithreading
# --eventthis
# --opposition
# --expense
# --contextualize
# bocoup.com/weblog/javascript-arduino-slide-controlling-servo-tutorial
# --0180
# --sliderservocontroljs
# --rotate
# --slider
# --9v
# --degrees
# --jumper
# --wart
# --cables
# --schematic
# bocoup.com/weblog/webkit-radial-gradients
# --boazse
# --heck
# --geckos
# --radial
# --boxshadow
# --maxvoltar
# --3inset
# --boazsendersmiscellaneousi
# --terse
# --inset
# bocoup.com/weblog/hubway-data-viz-hack-day
# --02210
# --1000am
# --hubway
# --oneyear
# --shabby
# --judges
# --bicycles
# --rsvp
# --metropolitan
# --mapc
# bocoup.com/about/bocouper/april-hart
# --pancho
# --allured
# --lefty
# --fondness
# --puppies
# --snuggling
# --drifted
# --awesomeness
# --behaved
# --charged
# bocoup.com/presentations/there-are-local-jquery-tables-in-your-area
# --launches
# --tables
# --<
# --jenn
# --schiffer
# --area
# -->
# --talks
# --table
# --local
# bocoup.com/weblog/node-stress-test-analysis
# --longpolling
# --serialization
# --utilization
# --demanding
# --bursts
# --optimizations
# --sockets
# --heartbeats
# --messagepack
# --simulated
# bocoup.com/education/online/screencasts/reducing-complexity-function
# --bh
# --photo
# --innovating
# --mastery
# --firsthand
# --creatively
# --educators
# --intensive
# --indepth
# --chicago
# bocoup.com/weblog/bocoup-on-air-robots-johnny-five
# --hangouts
# --internets
# --keyvalue
# --weak
# --serialport
# --johnny
# --arduinos
# --creations
# --geek
# --google+
# bocoup.com/weblog/info-hiding-in-js
# --obscurity
# --lookup
# --perinstance
# --randomlygenerated
# --coerced
# --perclass
# --dereference
# --secondly
# --remarkable
# --gang
# bocoup.com/about/bocouper/rick-waldron
# --sparkcore
# --idf2014
# --ricks
# --rngio
# --channeling
# --pinoccio
# --bean
# --establishing
# --blue
# --coengineered
# bocoup.com/weblog/random-numbers
# --linear
# --crypto
# --modulus
# --lcg
# --entropy
# --procedurally
# --pseudorandom
# --congruential
# --m
# --implementationdependent
# bocoup.com/weblog/tag/software-development-process/page/2
# --rocket
# --dance
# --minimizing
# --tours
# --stays
# --backandforthconfusionabout
# --markdown
# --whatcalldoeswhat
# --delivers
# --ingredient
# bocoup.com/careers/position/designer
# --designdriven
# --multidisciplinary
# --confidently
# --usercentered
# --fitness
# --gather
# --wireframes
# --personas
# --sustainable
# --mockups
# bocoup.com/weblog/developer-weeks
# --incubating
# --zone
# --interruptions
# --segments
# --rats
# --redo
# --hourlong
# --subconsciously
# --estimating
# --superhumanly
# bocoup.com/weblog/javascript-web-workers-from-basics-to-jquery-hive-part-iii
# --jqueryhivepollenjs
# --crossimplementation
# --thereafter
# --workers8js
# --errant
# --youth
# --clientmain
# --jqueryhivepollen
# --workers5js
# --workers6js
# bocoup.com/weblog/introducing-learnlayout
# --recommending
# --enlightening
# --04th
# --starttofinish
# --learnlayoutcom
# --beginners
# --suggestions
# --trouble
# --standalone
# --reference
# bocoup.com/work/jsi-family-planning-dashboard
# --preventative
# --wireframing
# --ideated
# --grantors
# --coached
# --affairs
# --federal
# --records
# --providers
# --jsi
# bocoup.com/weblog/node-stress-test-server
# --absolute
# --catastrophe
# --advised
# --diy
# --vanilla
# --nodeup
# --pulls
# --distro
# --prealpha
# --lifting
# bocoup.com/weblog/roost-san-diego
# --guided
# --developerfocused
# --webapplication
# --concluding
# --1213
# --diego
# --collaboratively
# --1011
# --attend
# --jqcon
# bocoup.com/weblog/welcome-ashley-williams
# --lune
# --erlang
# --mechanics
# --spends
# --orbital
# --pataphysical
# --méliès
# --22week
# --voyage
# --recipes
# bocoup.com/weblog/learn-css-layout-meets-latin-america
# --translations
# --chinese
# --german
# --struck
# --nonenglish
# --russian
# --farsi
# --portuguese
# --spanish
# --spanishlanguage
# bocoup.com/services/training/classes/building-server-side-apps-with-node-and-express
# --conditionals
# --clientserver
# --intermediate
# --spin
# --integrating
# --fits
# --routes
# --dirty
# --intro
# --relationship
# bocoup.com/weblog/tag/bocoup/page/2
# --ceros
# --carls
# --10up
# --zest
# --nodegamepad
# --pixelfies
# --administering
# --endusers
# --speaks
# --profile
# bocoup.com/weblog/tag/bocoup/page/3
# --manybills
# --bazaarvoice
# --donordirect
# --communicator
# --evelyns
# --contibutions
# --gravitas
# --brilliance
# --congressional
# --communites
# bocoup.com/weblog/author/rick-waldron
# --sparkcore
# --idf2014
# --ricks
# --rngio
# --channeling
# --pinoccio
# --bean
# --establishing
# --blue
# --coengineered
# bocoup.com/about/bocouper/pete-karl/page/2
# --liking
# --makesock
# --apache
# --bind
# --giving
# --chance
# --karl
# --port
# --pete
# --14
# bocoup.com/weblog/bocoup-training-atlanta
# --steal
# --seating
# --149
# --earlybird
# --tangled
# --win
# --venturing
# --tame
# --atlanta
# --conjunction
# bocoup.com/services/datavis
# --topcaliber
# --famine
# --somalia
# --instructional
# --academia
# --crisis
# --userfriendly
# --mapbased
# --144
# --flowcontrol
# bocoup.com/workat
# --insurance
# --disability
# --orientations
# --sexual
# --dental
# --transit
# --ppo
# --zealotry
# --discretionary
# --stewardship
# bocoup.com/careers/faq
# --interview
# --techpacity
# --candidacy
# --cultural
# --hypothetical
# --submitting
# --nuances
# --proceed
# --capacity
# --finish
# bocoup.com/weblog/welcome-kacie-cabral
# --kacie
# --learner
# --bristol
# --kacies
# --cabral
# --sooner
# --backgrounds
# --30th
# --studying
# --greeting
# bocoup.com/weblog/javascript-current-detection-with-johnny-five
# --acs712
# --30a
# --a0
# --programmatic
# --charted
# --screw
# --potentiometer
# --vcc
# --homework
# --optional
# bocoup.com/weblog/new-experiments-in-css-tooling
# --deawfulator
# --whitespaceonly
# --zjgbb
# --bxoir
# --djgbl
# --lauded
# --compiles
# --codename
# --endless
# --hackfree
# bocoup.com/weblog/tag/microprocessor/page/2
# --creations
# --geek
# --arduinos
# --electronics
# --microcenter
# --dancing
# --tuesday
# --wireless
# --hostclient
# --restrictive
# bocoup.com/weblog/welcome-richard-worth
# --knack
# --dojo
# --evangelizing
# --richard
# --13th
# --grid
# --pleased
# --evangelism
# --supporting
# --karl
# bocoup.com/presentations/jquery-is-a-swiss-army-knife
# --knife
# --swiss
# --army
# --versatility
# --ok
# --fits
# --shows
# --14
# --sontag
# --better
# bocoup.com/weblog/smaller-faster-websites
# --allcomparisonwwmonthly201408201408bar
# --320
# --standpoint
# --bandwidth
# --smartphones
# --61kb
# --oldfashioned
# --webp
# --perceived
# --webfont
# bocoup.com/weblog/bocoup-open-device-lab
# --gingerbread
# --ice
# --sandwich
# --404
# --kitkat
# --oses
# --cream
# --tweet
# --g2
# --kyocera
# bocoup.com/weblog/restart-apache-on-redhat-at
# --messed
# --httpd
# --restarting
# --redhat
# --restart
# --05th
# --apache
# --9
# --commands
# --havent
# bocoup.com/weblog/popcorn-js-0-2-released
# --butter
# --webmade
# --mitgpl
# --dual
# --popcorn
# --toolbelt
# --rethinks
# --ircmozillaorgpopcorn
# --licensed
# --passthrough
# bocoup.com/weblog/welcome-darius-kazemi
# --howto
# --shy
# --igda
# --gameplay
# --unconference
# --gameloop
# --mortem
# --analyst
# --pumped
# --sits
# bocoup.com/education/classes/javascript-for-engineers
# --bh
# --photo
# --innovating
# --mastery
# --firsthand
# --creatively
# --educators
# --intensive
# --indepth
# --chicago
# bocoup.com/weblog/welcome-kassandra-perch
# --checkout
# --sporting
# --perched
# --wearables
# --continuation
# --retailmenot
# --seats
# --hails
# --girl
# --chapter
# bocoup.com/weblog/recon2012-launch
# --engineio
# --scrapes
# --caption
# --prerecorded
# --phantomjs
# --voters
# --sentiment
# --mongodb
# --sosolimited
# --reconstitution
# bocoup.com/weblog/bring-out-your-bugs
# --colleges
# --handinhand
# --reaching
# --coursework
# --openhatch
# --advocates
# --nonprofit
# --prospective
# --nonetheless
# --women
# bocoup.com/presentations/fixing-these-jquery
# --methodologically
# --guts
# --pinch
# --thorniest
# --slain
# --thickets
# --paved
# --sooner
# --encounters
# --leg
# bocoup.com/weblog/visualizing-openvisconf
# --opencv
# --thumbnails
# --dominant
# --noise
# --keyframes
# --differencing
# --kmeans
# --condensed
# --loose
# --3dimensional
# bocoup.com/presentations/jort-sort
# --launches
# --harm
# --sorting
# --jenn
# --schiffer
# --frameworks
# --slides
# --whats
# --download
# --28
# bocoup.com/presentations/growing-up-with-backbone
# --lens
# --scoped
# --glimpse
# --evolution
# --shares
# --growing
# --es6
# --tim
# --talks
# --branyen
# bocoup.com/about/bocouper/irene-ros/page/3
# --padding
# --misostoryboard
# --house
# --r
# --responsible
# --flow
# --30
# --director
# --white
# --bringing
# bocoup.com/about/bocouper/irene-ros/page/2
# --abcs
# --responsibly
# --opengendertracker
# --d3chartjs
# --responsiveness
# --finder
# --surging
# --seas
# --v02
# --climate
# bocoup.com/presentations/jquerys-open-source-infrastructure
# --jquerys
# --frang
# --corey
# --infrastructure
# --13
# --2013
# --jun
# --source
# --open
# --newsletter
# bocoup.com/weblog/documenting-your-api
# --params
# --photoid=2345kj3
# --timestamping
# --wrongful
# --constraints
# --verbs
# --422
# --usersid=id
# --plurality
# --uncertainties
# bocoup.com/about/bocouper/adam-sontag
# --ringmarkrngio
# --commiter
# --curating
# --cohost
# --danley
# --carl
# --coengineered
# --podcast
# --played
# --bemvindo
# bocoup.com/weblog/welcome-adam-j-sontag
# --finishing
# --ajpiano
# --chocolate
# --familys
# --widget
# --cohost
# --freenode
# --factory
# --tassinari
# --nathaniel
# bocoup.com/about
# --dedicate
# --sphere
# --individuality
# --championing
# --inclusivity
# --continually
# --mcloughlin
# --hart
# --brendan
# --goddard
# bocoup.com/presentations/the-future-of-javascript
# --24
# --future
# --jan
# --waldron
# --rick
# --2013
# --newsletter
# --email
# --hellobocoupcom
# --touch
# bocoup.com/weblog/mayor-menino-and-vencorps-announce-welcome-home-challenge-winner
# --signedon
# --turillo
# --upstatement
# --winner
# --vencorps
# --mayor
# --menino
# --seed
# --funding
# --policies
# bocoup.com/presentations/code-architecture-with-d3-js
# --d3unconf
# --starts
# --keynote
# --organizing
# --30
# --d3chart
# --architecture
# --high
# --her
# --note
# bocoup.com/weblog/long-division-in-javascript
# --mathematical
# --reinforce
# --solidify
# --repetition
# --division
# --workplace
# --highschool
# --algorithms
# --student
# --math
# bocoup.com/services/training/classes/writing-testable-javascript
# --testworthy
# --testdriven
# --jsassessment
# --legacy
# --wondering
# --pitfalls
# --mocha
# --mix
# --exercises
# --sublimetext
# bocoup.com/about/bocouper/james-smith
# --videogame
# --marionette
# --interests
# --marionettejs
# --equally
# --james
# --likes
# --philosophy
# --physics
# --spending
# bocoup.com/weblog/performance-data-from-our-fieldrunners-webgl-demo
# --flame
# --64
# --demojs
# --4×4
# --8sample
# --dip
# --293
# --sum
# --edited
# --2000+
# bocoup.com/weblog/welcome-jess-klein
# --museum
# --curatorial
# --rubin
# --postit
# --sesame
# --jessica
# --peeled
# --startl
# --stealth
# --prints
# bocoup.com/weblog/introducing-moebio-framework
# --brainchild
# --shaping
# --visionary
# --numberlist
# --geometryrelated
# --empowers
# --networks
# --detecting
# --primitives
# --polish
# bocoup.com/weblog/text-rendering
# --prolonged
# --truck
# --fft
# --repaints
# --intendedor
# --spite
# --wings
# --desperately
# --noticable
# --webpagetestorg
# bocoup.com/work/rue-la-la
# --morale
# --exceed
# --educate
# --editable
# --angularjsbased
# --churn
# --organizationwide
# --productproject
# --nontechnical
# --velocity
# bocoup.com/about/bocouper/jory-burson/page/3
# --montreal
# --coo
# --washington
# --coming
# --introduction
# --goes
# --01
# --game
# --20
# --27
# bocoup.com/about/bocouper/jory-burson/page/2
# --cabral
# --kacie
# --sponsorship
# --atlanta
# --tour
# --london
# --tilde
# --bye
# --coo
# --essentials
# bocoup.com/weblog/javascript-arduino-programming-with-nodejs
# --duino
# --riding
# --monkey
# --julian
# --servosweepjs
# --avrgcc
# --ping
# --gautier
# --jagautier
# --membrane
# bocoup.com/weblog/tag/tools-workflow
# --someday
# --compile
# --wholly
# --gss
# --stylus
# --sheets
# --cdpath
# --sass
# --footsteps
# --painful
# bocoup.com/weblog/welcome-brendan-mcloughlin
# --audiopromise
# --contribitions
# --skimboarding
# --brendan
# --knockoutjs
# --paramount
# --mcloughlin
# --fullstack
# --eager
# --cassie
# bocoup.com/weblog/bocoup-�%99�-wordpress
# --allaround
# --noisemaker
# --remiss
# --joe
# --jasper
# --evko
# --degroot
# --html51
# --mcgill
# --oversaw
# bocoup.com/weblog/blocksplorer
# --perapi
# --scanning
# --gateway
# --scans
# --blockscanner
# --redisbased
# --s3
# --d3unconf
# --relied
# --blocksplorer
# bocoup.com/weblog/new-training-building-web-applications-with-backbone-js
# --pricing
# --3day
# --enforcing
# --battletested
# --backbonerelated
# --restful
# --partway
# --maximizing
# --disorganized
# --assistance
# bocoup.com/weblog/good-bye-pete
# --petes
# --employee
# --molding
# --saddened
# --sensibilities
# --strengthened
# --longtime
# --permeated
# --oversee
# --klocs
# bocoup.com/weblog/globalpost-syria-conflict
# --neighboring
# --measures
# --capita
# --cumulative
# --domestic
# --gross
# --slippy
# --pique
# --factoring
# --zoomed
# bocoup.com/weblog/welcome-z-goddard
# --curate
# --zed
# --kilt
# --unparalleled
# --oppportunity
# --zs
# --diskette
# --michael
# --british
# --packaging
# bocoup.com/presentations/building-jquery
# --gruntjs
# --everywhere
# --slides
# --download
# --customized
# --22
# --steps
# --easy
# --needs
# --pennisi
# bocoup.com/presentations/jquery-migrate-plugin
# --migrate
# --wonders
# --upgrade
# --assist
# --maintainers
# --explores
# --30
# --talks
# --unique
# --details
# bocoup.com/weblog/tag/design/page/2
# --someday
# --nitpick
# --condemn
# --wholly
# --restaurants
# --compile
# --downloads
# --complained
# --gss
# --accomodate
# bocoup.com/weblog/tag/design/page/3
# --flexbox
# --newlystablized
# --skeletal
# --shader
# --sosolimited
# --easytounderstand
# --scarcity
# --factual
# --tonight
# --pointed
# bocoup.com/weblog/tag/open-design-process
# --spanishlanguage
# --fist
# --dictionary
# --smiths
# --frustration
# --englishlanguage
# --shaking
# --spanish
# --forcing
# --translated
# bocoup.com/weblog/txjs-node-workshop
# --emailed
# --hapi
# --roostbocoupcom
# --foundational
# --refunded
# --attendance
# --signup
# --chai
# --jscs
# --tying
# bocoup.com/weblog/tag/data-visualization/page/4
# --jsartoolkit
# --augmented
# --wrapper
# --familiarizing
# --judges
# --bicycles
# --oneyear
# --shabby
# --metropolitan
# --alistair
# bocoup.com/weblog/tag/design/page/4
# --winding
# --whereever
# --quora
# --folk
# --accordion
# --prefab
# --peddled
# --lurking
# --disprove
# --unclean
# bocoup.com/education/classes/visualizing-data-with-d3.1
# --bh
# --photo
# --innovating
# --mastery
# --firsthand
# --creatively
# --educators
# --intensive
# --indepth
# --chicago
# bocoup.com/weblog/tag/client-side/page/2
# --infant
# --html5s
# --beneficial
# --xml
# --subtitles
# --showcase
# --credits
# --cammarata
# --multicore
# --nonblocking
# bocoup.com/education/classes/javascript-best-practices
# --bh
# --photo
# --innovating
# --mastery
# --firsthand
# --creatively
# --educators
# --intensive
# --indepth
# --chicago
# bocoup.com/about/bocouper/yannick-assogba
# --leans
# --academically
# --interhuman
# --computation
# --professionally
# --ibm
# --yannick
# --openvisconf
# --social
# --needles
# bocoup.com/weblog/global-name-data
# --baby
# --pat
# --classifier
# --births
# --classification
# --androgynous
# --classify
# --machinereadable
# --byline
# --kingdom
# bocoup.com/work/roost-chicago
# --homegrown
# --ranges
# --roostagram
# --introductory
# --roster
# --preceding
# --productionquality
# --widelyused
# --275
# --instructors
# bocoup.com/presentations/tim-branyen-jquery-templates
# --appssites
# --fallbacks
# --siteapp
# --disadvantages
# --partial
# --enhancement
# --applicable
# --ultimate
# --progressive
# --discusses
# bocoup.com/weblog/building-command-line-tools-in-node-with-liftoff
# --duplicates
# --invariably
# --systemwide
# --commanderjs
# --nearest
# --widespread
# --ancestor
# --variant
# --hacker
# --sees
# bocoup.com/weblog/extensible-web-manifesto
# --representatives
# --hoc
# --personalities
# --babel
# --implementers
# --facto
# --ad
# --solicit
# --standardistas
# --gatekeepers
# bocoup.com/weblog/tag/open-source
# --ela
# --vez
# --funcionam
# --colaborador
# --explorar
# --exemplos
# --vir
# --impressão
# --vão
# --ainda
# bocoup.com/about/bocouper/adam-sontag/page/3
# --fixing
# --ringmark
# --launch
# --director
# --04
# --27
# --sontag
# --newer
# --presentations
# --recent
# bocoup.com/about/bocouper/adam-sontag/page/2
# --knife
# --bosh
# --vim
# --swiss
# --army
# --sayre
# --trevor
# --sessions
# --goddard
# --ok
# bocoup.com/services/training/classes/building-web-applications-with-ember
# --handlebars
# --boilerplates
# --ambitious
# --controllers
# --routes
# --ideal
# --sublimetext
# --templating
# --philosophy
# --agenda
# bocoup.com/about/bocouper/ben-alman
# --trycatch
# --portland
# --francisco
# --san
# --31
# --catch
# --alman
# --grunt
# --ben
# --engineer
# bocoup.com/weblog/good-bye-dan
# --spearheaded
# --stretches
# --stewarded
# --bocoupcoms
# --transitioned
# --yearandahalf
# --firfoxos
# --memories
# --bazaarvoice
# --danheberden
# bocoup.com/about/bocouper/z-goddard
# --emscripten
# --cafes
# --inspires
# --doodles
# --shops
# --hovels
# --rust
# --poetry
# --tea
# --workplace
# bocoup.com/about/bocouper/lidza-louina
# --lidza
# --louina
# --fellow
# --20
# --presentations
# --jan
# --my
# --experience
# --posts
# --2014
# bocoup.com/weblog/tag/localization
# --spanishlanguage
# --fist
# --dictionary
# --smiths
# --frustration
# --englishlanguage
# --shaking
# --spanish
# --forcing
# --translated
# bocoup.com/about/bocouper/brendan-mcloughlin
# --baseball
# --brendan
# --mcloughlin
# --skiing
# --watching
# --security
# --enjoys
# --engineer
# --developing
# --technologies
# bocoup.com/education/classes/building-web-applications-with-backbone.1
# --bh
# --photo
# --innovating
# --mastery
# --firsthand
# --creatively
# --educators
# --intensive
# --indepth
# --chicago
# bocoup.com/weblog/author/corey-frang
# --stackoverflow
# --gnarf
# --rewrote
# --confessions
# --maintains
# --cdpath
# --pronouns
# --committer
# --scoping
# --hacking
# bocoup.com/presentations/grow-up-with-grunt
# --grunt
# --alman
# --ben
# --grow
# --28
# --2012
# --jun
# --up
# --newsletter
# --email
# bocoup.com/about/bocouper/sue-lockwood
# --nosql
# --godzilla
# --neuropsychology
# --loving
# --illustrator
# --baker
# --db
# --dribbble
# --drawings
# --fauxton
# bocoup.com/weblog/welcome-carl-danley
# --exuberant
# --delves
# --positively
# --carl
# --10up
# --ps3
# --carls
# --zest
# --plying
# --snes
# bocoup.com/weblog/tag/javascript-robotics
# --flipflop
# --sequential
# --deli
# --signs
# --wellproven
# --airports
# --grocery
# --alarm
# --colossus
# --194344
# bocoup.com/weblog/javascript-arduino-kinect-robot-arm
# --shoulder
# --pvector
# --wrist
# --lynxmotioncom
# --effector
# --kinectcontrolledrobotarmjs
# --xbox
# --360
# --emitted
# --borensteins
# bocoup.com/education/online/screencasts
# --bh
# --photo
# --innovating
# --mastery
# --firsthand
# --creatively
# --educators
# --intensive
# --indepth
# --chicago
# bocoup.com/weblog/sketchbook-cssconf
# --adekunle
# --holman
# --comforting
# --lea
# --sarah
# --lukas
# --believes
# --funniest
# --housandí
# --whimsy
# bocoup.com/weblog/author/claire-rittershaus
# --castles
# --shipshape
# --laughing
# --hikes
# --claire
# --shells
# --dogs
# --organizer
# --staying
# --heart
# bocoup.com/weblog/tag/server-side
# --wellandgood
# --shiny
# --sides
# --discovering
# --pertinent
# --suitable
# --secondscreen
# --productionready
# --websocket
# --unless
# bocoup.com/presentations/write-the-right-tests
# --subsystems
# --explains
# --distinct
# --collection
# --slides
# --download
# --tests
# --07
# --pennisi
# --understanding
# bocoup.com/services/education/writing-testable-javascript
# --untestable
# --hump
# --bdd
# --67
# --moderately
# --trainingbocoupcom
# --addictive
# --sept
# --jsassessment
# --testdriven
# bocoup.com/weblog/javascript-web-workers-safari-5-now-supports-complex-messages
# --rendererhtml
# --5s
# --rendererjs
# --resultsconsolejs
# --jsonobject
# --753316
# --boolean
# --workerjs
# --50
# --diligence
# bocoup.com/weblog/tag/data-visualization/page/3
# --shrouded
# --highlyinteractive
# --216
# --wellestablished
# --1617
# --examination
# --matias
# --bylines
# --mystery
# --combining
# bocoup.com/weblog/tag/tutorial/page/2
# --metaphor
# --1000+
# --crumble
# --weight
# --scatterplot
# --limitation
# --hostclient
# --usual
# --restrictive
# --flipflop
# bocoup.com/weblog/tag/tutorial/page/3
# --surely
# --slowly
# --visits
# --guiding
# --reviving
# --gaps
# --observations
# --irregularities
# --decent
# --laboratory
# bocoup.com/weblog/tag/testing
# --testings
# --nothings
# --cherry
# --unmaintainable
# --till
# --hurdle
# --deciphering
# --slog
# --necessity
# --skill
# bocoup.com/weblog/ringmark-gallery-pt1
# --ringmarks
# --visualized
# --unveiling
# --acid
# --wp75
# --dolphin
# --unbiased
# --237
# --meego
# --hd
# bocoup.com/weblog/welcome-earle-castledine
# --jsscala
# --mrspeaker
# --dare
# --omega500
# --doings
# --ludum
# --sauntering
# --confabulating
# --borough
# --sayings
# bocoup.com/presentations/side-projects-front-and-center
# --argues
# --employers
# --explorationnights
# --fullon
# --somebodys
# --empirejs
# --kadam
# --letting
# --weekends
# --spare
# bocoup.com/weblog/easily-test-jquery-pre-release-versions
# --cdn
# --unminified
# --rc
# --gistfile1js
# --xx0
# --releasecandidate
# --gistfile1html
# --frenzy
# --gistfile1txt
# --pointreleases
# bocoup.com/weblog/tag/data-visualization/page/2
# --shader
# --skeletal
# --accomodate
# --metaphor
# --easytounderstand
# --scarcity
# --factual
# --proceedings
# --crumble
# --1000+
# bocoup.com/weblog/welcome-kadam-white
# --kadam
# --coorganizers
# --casting
# --pickled
# --corporation
# --kadamwhite
# --taco
# --troupe
# --cabbage
# --impeccable
# bocoup.com/weblog/javascript-programming-esc-brushless-motor
# --intermediary
# --marks
# --breakthrough
# --coordination
# --nontrivial
# --commited
# --motors
# --motor
# --verifying
# --publishing
# bocoup.com/weblog/welcome-dan-heberden
# --powerhouse
# --javascriptjquery
# --spoken
# --amazons
# --bugfixes
# --strengthen
# --danheberden
# --infrastructural
# --dans
# --contributes
# bocoup.com/presentations/the-once-and-future-web
# --marquis
# --mat
# --wilto
# --28
# --future
# --once
# --jul
# --2015
# --by
# --newsletter
# bocoup.com/weblog/tag/mobile
# --facebooks
# --enterprise
# --vertical
# --succeed
# --coremobcoremobtests
# --canary
# --videoframetocanvas
# --vendors
# --dmv
# --normalized
# bocoup.com/consulting/coaching
# --nonprofits
# --fluency
# --storefront
# --cultivate
# --respected
# --institutions
# --la
# --mobilize
# --resilient
# --las
# bocoup.com/weblog/welcome-francis-gulotta
# --roborootercom
# --trifecta
# --manhattanjs
# --stellar
# --heartily
# --queensjs
# --customer
# --writings
# --peruse
# --dedication
# bocoup.com/presentations/the-house-that-open-source-built
# --adopted
# --heart
# --house
# --shares
# --principles
# --company
# --clients
# --16
# --better
# --irene
# bocoup.com/weblog/announcing-johnny-five-io
# --johnnyfiveorg
# --repos
# --lighting
# --demonstrating
# --material
# --backgrounds
# --ages
# --insufficient
# --realised
# --communitydriven
# bocoup.com/weblog/bob-goes-to-washington
# --northern
# --virginia
# --1820
# --911
# --aol
# --dulles
# --campus
# --oneandonly
# --courses
# --chat
# bocoup.com/weblog/author/isaac-durazo
# --beer
# --prettier
# --lone
# --exotic
# --gruntjs
# --executes
# --branding
# --latin
# --biking
# --summit
# bocoup.com/weblog/startup-data-trends
# --financing
# --valuation
# --cracked
# --followers
# --resorted
# --clicking
# --sparkline
# --rightmost
# --opaque
# --reorder
# bocoup.com/weblog/javascript-relay-with-johnny-five
# --nc
# --outlet
# --misuse
# --plugged
# --unplugged
# --operational
# --sensory
# --60038s
# --tinkerkit
# --indentifying
# bocoup.com/weblog/goodbye-ashley
# --ashleys
# --piep
# --colleague
# --ashley
# --flatiron
# --spearheading
# --miss
# --met
# --jsconf
# --24th
# bocoup.com/weblog/welcome-chris-bosh
# --gold
# --chrisbosh
# --twotime
# --miami
# --cartoons
# --olympic
# --congratulate
# --raptors
# --basketball
# --noncompetitive
# bocoup.com/weblog/introducing-grunt
# --gruntfile
# --grunting
# --minify
# --lint
# --concat
# --gonzález
# --concatenating
# --rakefile
# --poke
# --gruntrelated
# bocoup.com/weblog/whats-in-a-function-name
# --anonymous
# --existential
# --thrashing
# --nonstandard
# --formalizes
# --reasoning
# --divergent
# --boy
# --syntactically
# --cyclomatic
# bocoup.com/weblog/welcome-jim-vallandingham
# --flaneuring
# --adventuring
# --eating
# --seafood
# --himself
# --jims
# --traveler
# --wa
# --wholl
# --bioinformatics
# bocoup.com/weblog/author/mike-pennisi
# --srcdoc
# --backbonelayoutmanager
# --develops
# --mikes
# --privacy
# --dressup
# --interests
# --networking
# --polyfill
# --peer
# bocoup.com/weblog/designing-an-exponentiation-operator-for-javascript
# --es7
# --unary
# --arithmetic
# --multiplication
# --tc39ecma262
# --arithmentic
# --bnf
# --f
# --borrow
# --mental
# bocoup.com/presentations/wordpress-in-weird-places
# --precluding
# --wps
# --wp
# --editing
# --picked
# --choices
# --holds
# --weird
# --evolution
# --places
# bocoup.com/weblog/launching-ssrf
# --arsenal
# --flood
# --secondarily
# --thankful
# --d3charthorizontallegend
# --d3charttooltips
# --ssrfs
# --stamen
# --geographies
# --centrals
# bocoup.com/weblog/taking-a-peek-at-googles-new-in-page-analytics
# --giant
# --overlay
# --heatmap
# --urchin
# --crazyegg
# --clumsy
# --artillery
# --inpage
# --screencast
# --superb
# bocoup.com/services/design
# --impacted
# --lookandfeel
# --versatile
# --evocative
# --discerning
# --hbrorg
# --hbrs
# --grantees
# --anonymized
# --resilient
# bocoup.com/weblog/tag/performance/page/3
# --ecmatc39
# --weinstein
# --rafael
# --taskbased
# --flipped
# --262
# --excitedid
# --objectobserve
# --trick
# --inaugural
# bocoup.com/weblog/the-dimensions-of-web-design
# --ratios
# --ie7
# --10em
# --godemperor
# --osx
# --cluttered
# --hypercube
# --superstition
# --king
# --independentlyoperated
# bocoup.com/weblog/using-svg-patterns-as-fills
# --toolchain
# --classname
# --base64
# --nonsvg
# --patternfills
# --gradations
# --classnames
# --defs
# --compressed
# --encoded
# bocoup.com/weblog/tag/performance/page/2
# --skeletal
# --revolved
# --shader
# --dire
# --challengedevelopers
# --v04
# --modularize
# --immoral
# --nefarioussounding
# --afraid
# bocoup.com/weblog/author/boaz-sender
# --dotcom
# --interpreting
# --bientot
# --adopt
# --bye
# --six
# --ceo
# --translating
# --goodbye
# --businesses
# bocoup.com/about/bocouper/brian-j-brennan
# --sloths
# --diary
# --lisa
# --atrisk
# --frank
# --ventures
# --attract
# --tries
# --feelings
# --slam
# ...
# --06approach3drawcustomjs
# --emulate
# --05approach2runjs
# --association
# --positioning
# bocoup.com/weblog/announcing-openvis-conf
# --399
# --openvisconfcom
# --acquiring
# --transparency
# --sell
# --proposals
# --shrouded
# --earlybird
# --fostering
# --mystery
# bocoup.com/presentations/keynote-visualizing-data-responsibly
# --responsibly
# --keynote
# --visualizing
# --29
# --irene
# --ros
# --2013
# --mar
# --newsletter
# --email
# bocoup.com/weblog/au-revoir-tim
# --celebrate
# --smartest
# --missiondriven
# --wake
# --countless
# --21st
# --bye
# --integral
# --relationship
# --authored
# bocoup.com/about/bocouper/boaz-sender/page/4
# --lateral
# --ceo
# --2009
# --object
# --sender
# --boaz
# --newer
# --js
# --15
# --recent
# bocoup.com/about/bocouper/boaz-sender/page/3
# --graphaëljs
# --facelift
# --linechart
# --division
# --radial
# --sub
# --redhat
# --gradients
# --newsweek
# --burst
# bocoup.com/about/bocouper/boaz-sender/page/2
# --mayor
# --vencorps
# --rotoscoping
# --exploding
# --authsub
# --winner
# --menino
# --datatransfer
# --gamelab
# --contacts
# bocoup.com/work/the-guardian-somalia-famine
# --metanarrative
# --publication
# --harnessing
# --novel
# --architect
# --speeding
# --lens
# --famine
# --somalia
# --captured
# bocoup.com/weblog/a-facade-for-tooling-with-npm-scripts
# --alias
# --shortcuts
# --globallyinstalled
# --locallyinstalled
# --prepublish
# --rampup
# --founded
# --secondnature
# --poison
# --nodespecific
# bocoup.com/loft/lab
# --ma02196
# --961436
# --po
# --02109
# --marketplace
# --ma
# --faneuil
# --st
# --visit
# --market
# bocoup.com/about/bocouper/greg-smith
# --hourly
# --nom
# --scrum
# --restaurant
# --dinner
# --estimation
# --overflow
# --gsn
# --empty
# --experiments
# bocoup.com/work/firefox-os
# --ffos
# --televisions
# --stabilized
# --ramp
# --offtoday
# --html5based
# --acquaint
# --initiated
# --panasonic
# --empowered
# bocoup.com/weblog/author/greg-smith
# --hourly
# --nom
# --scrum
# --restaurant
# --dinner
# --estimation
# --overflow
# --gsn
# --empty
# --experiments
# bocoup.com/about/bocouper/sam-clearman
# --publishsubscribe
# --truthiness
# --clarksons
# --hull
# --compiling
# --enumerablemap
# --clearman
# --webworkers
# --sam
# --x
# bocoup.com/weblog/bocoup-screencasts
# --bitesized
# --digestible
# --tidy
# --backed
# --bocouptraining
# --ton
# --capture
# --dry
# --guiding
# --pipeline
# bocoup.com/weblog/welcome-brian-j-brennan
# --lp
# --river
# --shoegaze
# --bass
# --outfit
# --hollows
# --eastern
# --musician
# --brianloveswords
# --cat
# bocoup.com/weblog/miso-storyboard
# --aforementioned
# --storyboardexamplejs
# --showingdetails
# --intertwining
# --updatingdata
# --treemap
# --encapsulation
# --tear
# --transitioning
# --begins
# bocoup.com/about/bocouper/greg-smith/page/2
# --flexbox
# --boxbox
# --multiplayer
# --cloak
# --dimensions
# --keynote
# --dive
# --11
# --network
# --layout
# bocoup.com/weblog/tag/deployment/page/2
# --tld
# --hacks
# --httpd
# --binge
# --sick
# --redhat
# --sub
# --subdomain
# --foreign
# --money
# bocoup.com/weblog/d3-chart-v02
# --composing
# --phenomenon
# --supplement
# --longstanding
# --tooltips
# --kiss
# --simplicitys
# --stupid
# --regret
# --contingent
# bocoup.com/weblog/welcome-cowboy-ben-alman
# --bens
# --cowboy
# --benalmancom
# --nasty
# --cisco
# --belt
# --writings
# --greatly
# --repeatedly
# --cooking
# bocoup.com/education/classes/building-maintainable-javascript-applications
# --bh
# --photo
# --innovating
# --mastery
# --firsthand
# --creatively
# --educators
# --intensive
# --indepth
# --chicago
# bocoup.com/weblog/a-look-at-new-classes-from-bocoup
# --testability
# --loops
# --2122
# --recruit
# --enduring
# --wayside
# --dives
# --distinguish
# --volunteered
# --loom
# bocoup.com/weblog/making-a-rapbot
# --speech
# --couplet
# --rhyme
# --rhymes
# --couplets
# --rhyming
# --noun1
# --scan
# --appending
# --mc
# bocoup.com/services/training
# --bh
# --photo
# --innovating
# --mastery
# --firsthand
# --creatively
# --educators
# --intensive
# --indepth
# --chicago
# bocoup.com/weblog/javascript-laser-intrusion-detection-with-johnny-five
# --beam
# --lasers
# --200ω
# --photocells
# --d9
# --audible
# --emits
# --unbroken
# --reaction
# --actuated
# bocoup.com/weblog/welcome-adam-hyland
# --economist
# --assessing
# --intern
# --modeling
# --pop
# --11th
# --statistical
# --hyland
# --wikipedia
# --cassie
# bocoup.com/weblog/welcome-jory-burson
# --radio
# --budding
# --intuit
# --oklahoma
# --multimedia
# --disney
# --twin
# --mathworks
# --mass
# --trained
# bocoup.com/work/javascript-best-practices-with-bh-photo-video
# --leveling
# --retailer
# --owned
# --skillsets
# --13person
# --experiential
# --sat
# --premier
# --bestinclass
# --reinforced
# bocoup.com/weblog/welcome-trevor-sayre
# --trevorsayre
# --inexplicably
# --climbing
# --trevor
# --cryptic
# --cowork
# --planes
# --sayre
# --fold
# --rock
# bocoup.com/education/html5-game-dev
# --bh
# --photo
# --innovating
# --mastery
# --firsthand
# --creatively
# --educators
# --intensive
# --indepth
# --chicago
# bocoup.com/weblog/stereotropes-design
# --identifiable
# --tooltip
# --lavender
# --baggage
# --grandpa
# --substituting
# --explorable
# --excluded
# --manic
# --categorizable
# bocoup.com/weblog/tag/tools-workflow/page/3
# --appetite
# --grappled
# --dreamweavers
# --engorged
# --dealings
# --catching
# --substantiate
# --macvims
# --dreamweaver
# --leapt
# bocoup.com/weblog/tag/tools-workflow/page/2
# --wordnik
# --promisesbased
# --shopper
# --metaphoraminute
# --wordnikbb
# --80s
# --interfacing
# --freestyle
# --rap
# --rapbot
# bocoup.com/weblog/tag/deployment
# --wagnalls
# --funk
# --accidentally
# --makesock
# --config
# --upgrading
# --retreiving
# --webhook
# --postreceive
# --ereader
# bocoup.com/weblog/welcome-sam-bisbee
# --sbisbee
# --reebok
# --sag
# --woopid
# --sam
# --bisbee
# --boost
# --php
# --mongodb
# --couchdb
# bocoup.com/weblog/effective-unit-testing-with-amd
# --paths
# --luxuries
# --deterministic
# --engineeringspeak
# --coopers
# --gum
# --squirejs
# --fake
# --pathing
# --alikeyou
# bocoup.com/work/moebio-framework
# --publicfacing
# --fronts
# --licensing
# --modularity
# --moebio
# --canvasbased
# --santiago
# --ortiz
# --beta
# --toolkit
# bocoup.com/presentations/reusability-with-d3-chart
# --discusses
# --reusability
# --motivation
# --covers
# --d3chart
# --slides
# --download
# --exploring
# --visualizations
# --16
# bocoup.com/about/bocouper/adam-hyland
# --hyland
# --random
# --generation
# --17
# --global
# --name
# --presentations
# --adam
# --03
# --number
# bocoup.com/weblog/tag/client-side
# --smartphone
# --headers
# --clicker
# --propagated
# --environmentusually
# --useragent
# --spoofing
# --webrequest
# --law
# --mediacontrollers
# bocoup.com/weblog/tag/training/page/2
# --coordinator
# --tangled
# --dulles
# --aol
# --venturing
# --1820
# --txjss
# --oneandonly
# --virginia
# --911
# bocoup.com/weblog/tag/training/page/3
# --seat
# --disorganized
# --dabbled
# --val
# --struggled
# --lectures
# --primer
# --translates
# --299
# --beginner
# bocoup.com/weblog/nom
# --balsamiq
# --imaginary
# --commons
# --persuade
# --traceable
# --swiper
# --vibe
# --tingles
# --criticize
# --blueprints
# bocoup.com/weblog/announcing-voyager
# --perceptual
# --bridging
# --fees
# --ranked
# --toolset
# --luxury
# --closesourced
# --democratize
# --programmatic
# --stanford
# bocoup.com/services/training/classes/end-to-end-testing-and-continuous-integration
# --webdriver
# --enrolling
# --whys
# --determinism
# --behaviordriven
# --hows
# --driver
# --mix
# --exercises
# --abstraction
# bocoup.com/about/bocouper/bocoup
# --♥
# --resig
# --john
# --templates
# --wordpress
# --es6
# --advanced
# --present
# --tim
# --branyen
# bocoup.com/education/classes
# --bh
# --photo
# --innovating
# --mastery
# --firsthand
# --creatively
# --educators
# --intensive
# --indepth
# --chicago
# bocoup.com/weblog/welcome-eric-oconnor
# --dnssec
# --evening
# --cook
# --gbbopen
# --pizza
# --oconnor
# --cryptography
# --parsers
# --nginx
# --coworker
# bocoup.com/weblog/time-estimation-software-and-dinner
# --subway
# --010
# --symptoms
# --willingness
# --stakes
# --delays
# --715
# --profusely
# --707
# --apologizes
# bocoup.com/services/training/classes/building-maintainable-javascript-applications
# --intricacies
# --delve
# --gain
# --optimization
# --proof
# --universal
# --concatenation
# --fastpaced
# --lazy
# --exercises
# bocoup.com/work/jquery-foundation-infrastructure
# --jquerywpcontent
# --tens
# --backup
# --instrumental
# --denial
# --recovery
# --disaster
# --attacks
# --readily
# --demand
# bocoup.com/about/bocouper/tyler-kellen
# --diyer
# --solar
# --bookshelf
# --knex
# --offgrid
# --vermont
# --documentarian
# --tylers
# --homestead
# --mountain
# bocoup.com/weblog/using-datatransfer-with-jquery-events
# --filelist
# --dragdropfilereaderbrokenjs
# --urlifier
# --dragdropfilereaderworkshtml
# --dragdropping
# --filereaderexamplejs
# --dragenter
# --dragdropdatatransferhackjs
# --dragover
# --datauricom
# bocoup.com/weblog/tag/web-applications/page/2
# --france
# --internationally
# --netherlands
# --canada
# --reserve
# --threeday
# --germany
# --inaugural
# --roots
# --london
# bocoup.com/weblog/tag/web-applications/page/3
# --box2dweb
# --trainees
# --facebooks
# --interference
# --redefined
# --defending
# --threats
# --prerelease
# --coremobcoremobtests
# --threaten
# bocoup.com/work/world-economic-forum-global-competitiveness-report
# --wef
# --civil
# --dialogue
# --illuminating
# --wefs
# --quantity
# --government
# --sustainable
# --assessment
# --leaders
# bocoup.com/weblog/3pjs-css-delivery
# --compressor
# --preprocessors
# --errortolerant
# --vinegar
# --susceptible
# --drawback
# --pointits
# --recap
# --rainpress
# --emulation
# bocoup.com/weblog/author/irene-ros
# --eats
# --subsequently
# --thinks
# --delicious
# --blocksplorerorg
# --informative
# --shes
# --stories
# --food
# --fills
# bocoup.com/weblog/tag/design
# --ching
# --sketched
# --soaked
# --entertaining
# --backchannel
# --badoom
# --landmark
# --broadway
# --speckling
# --carolines
# bocoup.com/weblog/announcing-summer-2014-classes
# --multiclass
# --curated
# --lowvolume
# --sleeves
# --complemented
# --discount
# --webpack
# --browserify
# --tracks
# --muchloved
# bocoup.com/presentations/bringing-data-to-client-side-apps
# --bringing
# --clientside
# --06
# --apps
# --oct
# --irene
# --ros
# --2012
# --your
# --newsletter
# bocoup.com/weblog/es2015-nightmarefile
# --deseret
# --annex
# --countdown
# --snippet
# --token
# --threatened
# --forbids
# --incompatibility
# --incompatibilities
# --severity
# bocoup.com/weblog/shell-hacking-cdpath
# --executable
# --zsh
# --rpm
# --blown
# --revelation
# --bashcompletion
# --posix
# --macports
# --remarked
# --brew
# bocoup.com/contact
# --315
# --church
# --10013
# --3792752
# --ny
# --02196
# --617
# --4a
# --street
# --ma
# bocoup.com/weblog/intel-galileo-autonomous-navigation-rover
# --mounted
# --turnbyturn
# --chassis
# --locomotion
# --stream
# --hitec
# --rovers
# --torque
# --tooth
# --ir
# bocoup.com/weblog/think-long-term-focus-short-term
# --wasteful
# --coursecorrecting
# --thinker
# --god
# --projectspeak
# --nitty
# --distilling
# --jack
# --endgoal
# --balances
# bocoup.com/weblog/sessions-the-vim-feature-you-probably-arent-using
# --digs
# --bake
# --cozy
# --espcially
# --viminfo
# --pleasure
# --sessionvim
# --partisans
# --persist
# --overwite
# bocoup.com/work/npm-by-numbers
# --depended
# --breakdown
# --99000
# --revealed
# --dependents
# --57
# --npms
# --contrast
# --recognizing
# --conducted
# bocoup.com/weblog/synchronizing-html5-slides-with-node-js
# --listens
# --swipe
# --clientjs
# --hashchange
# --manipulates
# --distort
# --presenter
# --controllermarkuphtml
# --elegantly
# --controllerhtml
# bocoup.com/about/bocouper/reconbot
# --league
# --francis
# --wizard
# --schools
# --levo
# --highbridge
# --consulted
# --vp
# --capital
# --joy
# bocoup.com/weblog/author/adam-hyland
# --hyland
# --random
# --generation
# --17
# --global
# --name
# --presentations
# --adam
# --03
# --number
# bocoup.com/weblog/introducing-d3-chart
# --20000line
# --mixins
# --delegate
# --unchain
# --curse
# --02definejs
# --seamless
# --moused
# --07fulllayerjs
# --decoupled
# bocoup.com/weblog/author/jasmin-jata
# --ceramic
# --rose
# --kelleher
# --cephalopod
# --reveling
# --biology
# --scientific
# --outlook
# --unknown
# --overlords
# bocoup.com/weblog/learning-three-js-with-real-world-challenges-that-have-already-been-solved
# --object3d
# --hacky
# --nyt
# --dolly
# --object3ds
# --vertices
# --365
# --nyts
# --geometries
# --roy
# bocoup.com/weblog/category/open-web-apps
# --openwebapps
# --hookflash
# --peertopeer
# --spirits
# --kindred
# --mediarich
# --privilege
# --browserbased
# --peer
# --frontiers
# bocoup.com/weblog/welcome-tim-branyen
# --liberty
# --trump
# --cobbler
# --mutual
# --monstercom
# --networks
# --apijquerycom
# --tbranyen
# --caliber
# --blackberry
# bocoup.com/work/modern-web-deployment-workflow
# --discipline
# --standardizing
# --faint
# --repeatably
# --risky
# --robustly
# --playbooks
# --webapp
# --timesaving
# --databases
# bocoup.com/loft/events/2011/tim-branyen-jquery-templates
# --ma02196
# --961436
# --po
# --02109
# --marketplace
# --ma
# --faneuil
# --st
# --visit
# --market
# bocoup.com/weblog/reusability-with-d3.1
# --modifiable
# --refactored
# --fading
# --interpretations
# --interpretation
# --coloredlabel
# --pejorative
# --lowtech
# --chord
# --manages
# bocoup.com/weblog/tag/tutorial
# --emoji
# --affirmative
# --coveted
# --reviewed
# --printers
# --dollar
# --satisfied
# --timey
# --farmtax
# --treasure
# bocoup.com/work/the-guardian-usaid-food
# --contracts
# --wheat
# --sold
# --inkind
# --sorghum
# --investigative
# --weave
# --controversial
# --buying
# --publication
# bocoup.com/weblog/padding-time-series-with-r
# --gradual
# --analysing
# --cleaning
# --pad
# --zero
# --quickest
# --gaps
# --settled
# --computing
# --observations
# bocoup.com/weblog/bonjour-gare-du-nord
# --neighbors
# --situated
# --causeway
# --fondly
# --239
# --doors
# --fort
# --spaces
# --historic
# --spring
# bocoup.com/work/duolingo
# --duolingo
# --40+
# --duolingocom
# --doubles
# --crowdsourced
# --audits
# --boosting
# --lowerend
# --audit
# --duolingos
# bocoup.com/about/bocouper/boaz-sender
# --dotcom
# --interpreting
# --bientot
# --adopt
# --bye
# --six
# --ceo
# --translating
# --goodbye
# --businesses
# bocoup.com/weblog/tearing-grunt-apart
# --grunts
# --v03x
# --reams
# --middleware
# --mcilroy
# --reallive
# --summarized
# --supercharging
# --v05
# --yaml
# bocoup.com/weblog/stabilizing-es6
# --lacks
# --prioritizing
# --outlawing
# --daunting
# --test262s
# --ambiguities
# --starters
# --rocksolid
# --ropes
# --iifes
# bocoup.com/weblog/page/3
# --linguistic
# --scrumspecific
# --piep
# --methodologies
# --notions
# --webmaker
# --colleague
# --isolation
# --xray
# --microcredentials
# bocoup.com/weblog/page/2
# --eventos
# --tais
# --comunidade
# --subrepresentados
# --neste
# --underrepresented
# --estudos
# --acreditamos
# --oferecer
# --oslo
# bocoup.com/education/classes/visualizing-data-with-d3
# --bh
# --photo
# --innovating
# --mastery
# --firsthand
# --creatively
# --educators
# --intensive
# --indepth
# --chicago
# bocoup.com/weblog/page/5
# --adventure
# --fantastical
# --programatically
# --veritable
# --movement
# --wearables
# --retailmenot
# --brians
# --15000
# --nodeschool
# bocoup.com/weblog/page/4
# --ela
# --vez
# --funcionam
# --colaborador
# --explorar
# --exemplos
# --vir
# --impressão
# --vão
# --algum
# bocoup.com/services/training/classes/web-developer-tools-and-workflow
# --beautifying
# --hinting
# --minifying
# --automation
# --reload
# --instruction
# --linting
# --intermediate
# --efficient
# --dirty
# bocoup.com/weblog/javascript-webrtc-opera-mobile-12
# --piping
# --1977
# --~30fps
# --camera
# --nexus
# --youtube
# --watching
# --demonstrates
# --canary
# --dmv
# bocoup.com/weblog/javascript-web-workers-from-basics-to-jquery-hive-part-ii-browser-implementations
# --eval
# --booleans
# --irresponsibly
# --pipes
# --revolves
# --chromethey
# --workers4js
# --irresponsible
# --excellently
# --workers3js
# bocoup.com/weblog/author/dan-heberden
# --prerelease
# --gith
# --webhooks
# --versions
# --gaia
# --heberden
# --dan
# --05
# --easily
# --mozilla
# bocoup.com/about/bocouper/pete-karl
# --bisbee
# --peek
# --inpage
# --writers
# --googles
# --sam
# --cassie
# --irwin
# --richard
# --analytics
# bocoup.com/presentations/the-past-present-and-future-of-responsive-images
# --presents
# --craft
# --present
# --images
# --marquis
# --mat
# --01
# --responsive
# --future
# --past
# bocoup.com/weblog/new-game-tickets-on-sale
# --hilleman
# --gamesalad
# --ea
# --moblyng
# --249
# --stride
# --daylong
# --industrys
# --spil
# --349
# bocoup.com/education/classes/building-web-applications-with-backbone
# --bh
# --photo
# --innovating
# --mastery
# --firsthand
# --creatively
# --educators
# --intensive
# --indepth
# --chicago
# bocoup.com/weblog/javascript-web-workers-opera-10-60-beta-supports-complex-messages
# --pleasing
# --1060
# --rendererworker
# --beta
# --postmessage
# --workers
# --17th
# --gist
# --supports
# --opera
# bocoup.com/work/tessel-2
# --tinkerers
# --successor
# --lowcost
# --easyup
# --maker
# --embeddable
# --expressively
# --actuators
# --limitless
# --webconnected
# bocoup.com/weblog/tag/testing/page/2
# --14000
# --837
# --mention
# --collect
# --samples
# --facebooks
# --prerelease
# --coremobcoremobtests
# --sports
# --quarantined
# bocoup.com/work/visualizing-data-with-d3-js-training
# --battlehardened
# --idiosyncrasies
# --javascripters
# --equips
# --steep
# --strives
# --widelyused
# --onsite
# --librarys
# --shortcomings
# bocoup.com/weblog/intel-galileo-javascript-nodejs
# --espruino
# --soc
# --shields
# --fullfilled
# --tre
# --kiselev
# --inputoutput
# --firmatajs
# --bipedal
# --sparkio
# bocoup.com/weblog/javascript-arduino-digital-clock-johnny-five
# --8digit
# --crummy
# --digit
# --unequivocally
# --ie4
# --decadeandahalflater
# --tube
# --verbatim
# --acquire
# --eversoslightly

# %% [markdown]
# ## Next Steps

# %% [markdown]
# - Nearest-neighbor similiarity between pages
